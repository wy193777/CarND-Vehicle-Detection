# %% [markdown]
# # Imports

# %%
import svc
import matplotlib.pyplot as plt
from scipy import misc
import matplotlib.gridspec as gridspec
import imageio
imageio.plugins.ffmpeg.download()
import pipeline
import glob
# %matplotlib inline
# Out:
# /home/shenghan/.local/lib/python3.5/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
def generate_hog_images(image):
    img = svc.convert_color(image, 'YCrCb')
    virs = []
    for channel in [0, 1, 2]:
        _, vir = svc.get_hog_features(img[:, :, channel], vis=True)
        virs.append(vir)
    return virs

# %%
car = misc.imread('./examples/car.png')
virs = [car] + generate_hog_images(car)
titles = ['Original', 'CH Y', 'CH Cr', 'CH Cb']
for idx, vir in enumerate(zip(virs, titles)):
    plt.subplot(1, 4, idx+1)
    plt.imshow(vir[0])
    plt.title(vir[1])
plt.show()

# %%
notcar = misc.imread('./examples/notcar.png')
virs = [notcar] + generate_hog_images(notcar)
titles = ['Original', 'CH Y', 'CH Cr', 'CH Cb']
for idx, vir in enumerate(zip(virs, titles)):
    plt.subplot(1, 4, idx+1)
    plt.imshow(vir[0])
    plt.title(vir[1])
plt.show()

# %%
processor, svc_scaler = pipeline.init_pipeline()
scales = [1.0, 1.2, 1.4, 1.6, 1.8, 2.0, 2.2, 2.4]
rects = processor.find_cars_scale(misc.imread('test_images/test1.jpg'), vir=True)
for idx, f_img in enumerate(zip(rects, scales)):
#     plt.subplot(1, 11, idx+1)
    plt.imshow(f_img[0])
    plt.title('Scale: {}'.format(f_img[1]))
    
    plt.show()

# %%
process, svc_scaler = pipeline.init_pipeline()
for path in glob.glob('test_images/*.jpg'):
    img = misc.imread(path)
    bbox_list = process.find_cars_scale(img)
    heatmap = svc.add_heat(bbox_list, threshold=0)
    misc.imsave(
        'test_images_output/heatmap_' + Path(path).name,
        np.clip(heatmap, 0, 255)
    )
    out_img = svc.draw_labeled_bboxes(img, heatmap)
    plt.subplot(121)
    plt.imshow(out_img)
    plt.subplot(122)
    plt.imshow(heatmap, cmap='hot')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-02962ab9ac2f> in <module>()
#       1 process, svc_scaler = pipeline.init_pipeline()
# ----> 2 for path in glob.glob('test_images/*.jpg'):
#       3     img = misc.imread(path)
#       4     bbox_list = process.find_cars_scale(img)
#       5     heatmap = svc.add_heat(bbox_list, threshold=0)
#
# NameError: name 'glob' is not defined
